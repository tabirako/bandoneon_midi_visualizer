# %%
with open('mappings.js', 'r', encoding='utf-8') as f:
    # 1. ファイル全体を1つの文字列として読み込む場合
    text = f.read()
    print(text)

    # 2. 1行ずつ読み込んで処理する場合
    for line in f:
        print(line.strip())
# Out:
# window.defaultMappings = {
#   "142": [
#     {
#       "id": 1,
#       "side": "left",
#       "label": "B1",
#       "x": 0.08,
#       "y": 0.08,
#       "push": {
#         "note": 33,
#         "color": "hsl(104 70% 75%)"
#       },
#       "pull": {
#         "note": 34,
#         "color": "hsl(104 70% 75%)"
#       }
#     },
#     {
#       "id": 2,
#       "side": "left",
#       "label": "B2",
#       "x": 0.19,
#       "y": 0.08,
#       "push": {
#         "note": 34,
#         "color": "hsl(104 70% 75%)"
#       },
#       "pull": {
#         "note": 36,
#         "color": "hsl(146 70% 75%)"
#       }
#     },
#     {
#       "id": 3,
#       "side": "left",
#       "label": "B3",
#       "x": 0.3,
#       "y": 0.08,
#       "push": {
#         "note": 35,
#         "color": "hsl(104 70% 75%)"
#       },
#       "pull": {
#         "note": 38,
#         "color": "hsl(146 70% 75%)"
#       }
#     },
#     {
#       "id": 4,
#       "side": "left",
# ...

# %%
for i in f:
    print(i)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 for i in f:
#       2     print(i)
#
# ValueError: I/O operation on closed file.
